# %% [markdown]
# # Imports

# %%
# Add parent directory to Python path for imports
import sys
from pathlib import Path

# Get the repository root (parent of tests directory)
repo_root = Path(__file__).parent.parent if '__file__' in globals() else Path.cwd().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))
    
print(f"Added {repo_root} to Python path")
# Out:
# Added c:\Code\DL\bbosis\Hongyuan-Babesiosis to Python path

# %%
from core.training.ModelConfig import TrainingConfig
from core.training.BagDataset import EmbeddingBagDataset
from core.training.trainer import train

# %% [markdown]
# ## Setup Test Config

# %%
config = TrainingConfig(
    embeddings_path= Path(r"C:\Code\DL\bbosis\Hongyuan-Babesiosis\data\test\tensors\embeddings.pt"),
    labels_path= Path(r"C:\Code\DL\bbosis\Hongyuan-Babesiosis\data\test\tensors\labels.pt"),
    output_dir= Path("runs/test_run_mil"),
    epochs=5,
    batch_size=1,
    learning_rate=5e-5,
    weight_decay=0.01,
    max_tiles=10,
    checkpoint_every=1,
    seed=42
)

# %%
dataset = EmbeddingBagDataset(
    embeddings_path=config.embeddings_path,
    labels_path=config.labels_path,
    max_tiles=config.max_tiles
)

len(dataset)
# Out:
# 16

# %%
train(config=config)
# Out:
# c:\Code\DL\bbosis\Hongyuan-Babesiosis\core\training\BagDataset.py:68: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   raw_entries = torch.load(self.embeddings_path, map_location="cpu")
# c:\Code\DL\bbosis\Hongyuan-Babesiosis\core\training\BagDataset.py:70: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   labels_tensor = torch.load(labels_path, map_location="cpu")
# Epoch 1/5
#   Train loss: 0.7114  accuracy: 0.5385  precision: 0.3333  roc_auc: 0.5000  avg_prec: 0.3604
#   Val   loss: 0.3676  accuracy: 1.0000  precision: 0.0000  roc_auc: nan  avg_prec: nan
#
# Epoch 2/5
#   Train loss: 0.6688  accuracy: 0.6923  precision: 0.0000  roc_auc: 0.3611  avg_prec: 0.4575
#   Val   loss: 0.1990  accuracy: 1.0000  precision: 0.0000  roc_auc: nan  avg_prec: nan
#
# Epoch 3/5
#   Train loss: 0.6104  accuracy: 0.6923  precision: 0.0000  roc_auc: 0.6944  avg_prec: 0.6500
#   Val   loss: 0.3328  accuracy: 1.0000  precision: 0.0000  roc_auc: nan  avg_prec: nan
#
# Epoch 4/5
#   Train loss: 0.5909  accuracy: 0.6923  precision: 0.0000  roc_auc: 0.8056  avg_prec: 0.6845
#   Val   loss: 0.4081  accuracy: 1.0000  precision: 0.0000  roc_auc: nan  avg_prec: nan
#
# Epoch 5/5
#   Train loss: 0.6030  accuracy: 0.6923  precision: 0.0000  roc_auc: 0.6667  avg_prec: 0.4988
#   Val   loss: 0.4961  accuracy: 1.0000  precision: 0.0000  roc_auc: nan  avg_prec: nan
# Best checkpoint based on ROC-AUC stored in runs\test_run_mil\epoch_005
# Training history written to runs\test_run_mil\training_history.json
